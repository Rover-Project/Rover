# %% [markdown]
# 1. Instalação do Ambiente

# %%
# !pip install ultralytics roboflow
# !pip install tensorflow # Necessário apenas para exportação TFLite

from ultralytics import YOLO
from roboflow import Roboflow
import os
from google.colab import files

# Verificação de GPU
# !nvidia-smi
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.235-py3-none-any.whl.metadata (37 kB)
# Collecting roboflow
#   Downloading roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2025.11.12)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.235-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.7 MB/s eta 0:00:00
# Downloading roboflow-1.2.11-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 10.1 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.0 MB/s eta 0:00:00
# Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 69.9 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.2-cp312-cp312-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 84.7 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, opencv-python-headless, idna, ultralytics-thop, roboflow, ultralytics
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.1.1 pillow-avif-plugin-1.5.2 roboflow-1.2.11 ultralytics-8.3.235 ultralytics-thop-2.0.18
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Tue Dec  9 14:12:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# 2. Baixando o modelo disponível no Roboflow

# %%
API_KEY = "NBuz1fzAyyvvir6ANRBW" # <--- Chave da equipe criada pelo Guto
WORKSPACE = "roverlib"
PROJECT = "red-yyvye-i0y4k"
VERSION = 2

# Download
rf = Roboflow(api_key=API_KEY)
project = rf.workspace(WORKSPACE).project(PROJECT)
dataset = project.version(VERSION).download("yolov8")  #pascal voc -> tensorflow //

# Identifica o caminho da pasta baixada automaticamente
dataset_path = dataset.location
print(f"Dataset baixado em: {dataset_path}")

# Verifica a estrutura das pastas (Train, Valid, Test)
train_dir = os.path.join(dataset_path, "train")
valid_dir = os.path.join(dataset_path, "valid")
test_dir = os.path.join(dataset_path, "test")

print(f"Diretório de Treino: {train_dir}")
print(f"Diretório de Validação: {valid_dir}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in red-2 to yolov8:: 100%|██████████| 15835/15835 [00:00<00:00, 30338.65it/s]
# Extracting Dataset Version Zip to red-2 in yolov8:: 100%|██████████| 1866/1866 [00:00<00:00, 4019.33it/s]
# Dataset baixado em: /content/red-2
# Diretório de Treino: /content/red-2/train
# Diretório de Validação: /content/red-2/valid

# %% [markdown]
# 4. Treinamento do Modelo

# %%
print("Iniciando treinamento YOLOv8 Nano...")

model = YOLO('yolov8n.pt')      # model='yolov8n.pt': Versão Nano (mais rápida para Raspberry Pi)

results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=100,
    imgsz=640,
    batch=32,        # Definiu tamanho do lote
    patience=20,     # Espera 20 épocas sem melhora antes de parar
    plots=True
)
# Out:
# Iniciando treinamento YOLOv8 Nano...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 116.0MB/s 0.1s
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/red-2/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 29.3MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 129 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 69.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 778.7±446.5 MB/s, size: 19.2 KB)
# train: Scanning /content/red-2/train/labels... 741 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 741/741 2.5Kit/s 0.3s
# train: New cache created: /content/red-2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 271.2±115.4 MB/s, size: 10.5 KB)
# val: Scanning /content/red-2/valid/labels... 93 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 93/93 1.9Kit/s 0.1s
# val: New cache created: /content/red-2/valid/labels.cache
# Plotting labels to /content/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.96G      1.181      1.955      1.028         24        640: 100% ━━━━━━━━━━━━ 24/24 1.9it/s 12.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.6s/it 3.1s
#                    all         93        300     0.0286          1      0.968      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.39G      1.118     0.8149      1.029         25        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                    all         93        300       0.02      0.997      0.554       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.42G       1.02      0.683     0.9859         37        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                    all         93        300      0.992       0.81      0.933      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.44G      1.001     0.6277     0.9941         26        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                    all         93        300      0.922       0.96      0.971      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.45G     0.9821      0.602     0.9796         40        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         93        300      0.978      0.863      0.921      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.47G     0.9977      0.568      1.003         31        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                    all         93        300      0.993          1      0.995      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.49G      1.018     0.5525     0.9991         38        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         93        300      0.997      0.999      0.995      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.51G     0.9464     0.5032     0.9853         30        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1      0.999      0.995      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.52G     0.9046     0.4717     0.9621         33        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         93        300          1          1      0.995      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.54G     0.8691     0.4653     0.9649         39        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300      0.999          1      0.995      0.679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.56G      0.866     0.4489     0.9608         26        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.57G     0.8497     0.4359     0.9535         25        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.6s
#                    all         93        300      0.999          1      0.995      0.823
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100       4.6G     0.8572      0.432     0.9593         18        640: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2s
#                    all         93        300          1          1      0.995      0.805
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.61G     0.8386     0.4156     0.9472         22        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1      0.996      0.995      0.792
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.62G     0.8209     0.4025     0.9423         33        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         93        300          1          1      0.995      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.64G     0.8186     0.4021      0.945         28        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         93        300      0.997          1      0.995      0.813
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.66G     0.8345     0.3966     0.9504         25        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         93        300      0.999          1      0.995      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.68G     0.8316     0.3963     0.9468         29        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.69G     0.7723     0.3778     0.9252         25        640: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.4s
#                    all         93        300          1          1      0.995       0.82
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.71G     0.8078      0.386     0.9428         37        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.1s
#                    all         93        300          1          1      0.995      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.73G     0.7701     0.3771     0.9265         28        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         93        300          1          1      0.995      0.811
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      4.74G     0.7511     0.3669     0.9215         27        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      4.76G     0.7573     0.3579     0.9201         36        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                    all         93        300          1          1      0.995       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      4.78G     0.7622     0.3614     0.9243         34        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1s
#                    all         93        300          1          1      0.995       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      4.79G     0.7397     0.3558     0.9104         39        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                    all         93        300          1          1      0.995      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      4.81G     0.7561     0.3592       0.92         21        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                    all         93        300          1          1      0.995      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      4.83G     0.7339      0.359     0.9265         13        640: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.3s
#                    all         93        300          1          1      0.995      0.885
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      4.85G     0.7121     0.3516     0.9062         37        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1s
#                    all         93        300      0.998          1      0.995      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      4.86G     0.7196     0.3474     0.9081         33        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                    all         93        300          1          1      0.995      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      4.88G     0.7307     0.3447     0.9129         21        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1s
#                    all         93        300          1          1      0.995      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100       4.9G     0.7388     0.3546     0.9173         26        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      4.91G     0.7068     0.3375     0.9032         27        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         93        300          1          1      0.995      0.819
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      4.93G     0.7038      0.336     0.9068         29        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                    all         93        300          1          1      0.995      0.833
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      4.95G     0.6942     0.3305     0.8984         32        640: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.3s
#                    all         93        300          1          1      0.995      0.904
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      4.97G     0.7013     0.3385     0.9056         21        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         93        300          1          1      0.995      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      4.98G     0.6788     0.3249     0.8994         35        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.906
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100         5G     0.6691     0.3203     0.8932         30        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      5.02G     0.6814     0.3247      0.897         37        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1s
#                    all         93        300          1          1      0.995      0.888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      5.03G     0.6673     0.3209     0.8982         28        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      5.05G     0.6838     0.3267     0.8957         29        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                    all         93        300          1          1      0.995      0.885
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      5.07G     0.6791     0.3259     0.8903         37        640: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.5s
#                    all         93        300          1          1      0.995      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      5.09G     0.6651     0.3134     0.8905         36        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      5.11G      0.651     0.3068     0.8965         21        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.899
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      5.12G     0.6619     0.3125      0.895         38        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                    all         93        300          1          1      0.995      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      5.14G     0.6572     0.3139     0.8909         27        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.9s
#                    all         93        300          1          1      0.995      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      5.15G     0.6196     0.3002      0.881         35        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         93        300          1          1      0.995      0.904
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      5.17G     0.6461     0.3068     0.8843         26        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                    all         93        300          1          1      0.995       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      5.19G     0.6321     0.3038     0.8821         30        640: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                    all         93        300          1          1      0.995      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      5.21G      0.642     0.3022     0.8857         19        640: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         93        300          1          1      0.995      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      5.22G     0.6317      0.302       0.88         25        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                    all         93        300          1          1      0.995      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      5.24G     0.6262     0.3082     0.8863         29        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      5.26G     0.6254     0.2973     0.8786         30        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      5.27G     0.6301     0.2988     0.8767         34        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         93        300          1          1      0.995      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      5.29G     0.6154     0.2971     0.8777         33        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                    all         93        300          1          1      0.995       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      5.31G     0.6176     0.2929     0.8899         24        640: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.3s
#                    all         93        300          1          1      0.995      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      5.32G     0.6122     0.2894     0.8783         29        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.909
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      5.34G     0.6236      0.291     0.8941         19        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         93        300          1          1      0.995      0.916
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      5.36G      0.608     0.2923     0.8748         28        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         93        300          1          1      0.995      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      5.38G     0.6246     0.2917      0.881         25        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         93        300          1          1      0.995      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100       5.4G     0.5968     0.2851     0.8784         15        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         93        300          1          1      0.995      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      5.41G     0.5845      0.276     0.8704         31        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                    all         93        300          1          1      0.995      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      5.43G     0.5813     0.2819     0.8688         22        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                    all         93        300          1          1      0.995      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      5.44G     0.6189     0.2885     0.8778         29        640: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         93        300          1          1      0.995      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      5.46G     0.5744     0.2742     0.8651         14        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         93        300          1          1      0.995      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      5.48G     0.5602     0.2707     0.8595         19        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         93        300          1          1      0.995      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      5.49G     0.5772     0.2767     0.8683         33        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                    all         93        300          1          1      0.995      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      5.51G     0.5767     0.2733     0.8663         24        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                    all         93        300          1          1      0.995      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      5.53G      0.578     0.2693     0.8651         26        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         93        300          1          1      0.995      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      5.55G     0.5628     0.2665     0.8605         40        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                    all         93        300          1          1      0.995      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      5.56G     0.5667     0.2667     0.8671         44        640: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                    all         93        300          1          1      0.995      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      5.58G     0.5632     0.2672     0.8642         26        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100       5.6G     0.5666     0.2658     0.8648         34        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      5.61G     0.5534     0.2635     0.8589         40        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1s
#                    all         93        300          1          1      0.995      0.934
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      5.63G     0.5661     0.2676     0.8695         21        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         93        300          1          1      0.995      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      5.65G     0.5606     0.2634     0.8646         32        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         93        300          1          1      0.995      0.932
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      5.67G     0.5369      0.255     0.8532         18        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.6it/s 1.3s
#                    all         93        300          1          1      0.995      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      5.69G     0.5481     0.2585     0.8604         17        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s
#                    all         93        300          1          1      0.995       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100       5.7G     0.5339     0.2521     0.8582         23        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         93        300          1          1      0.995      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      5.72G      0.529     0.2524     0.8511         23        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      5.73G     0.5328     0.2517     0.8553         32        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                    all         93        300          1          1      0.995      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      5.76G     0.5404      0.251     0.8565         22        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                    all         93        300          1          1      0.995      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      5.77G     0.5404     0.2504     0.8553         29        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         93        300          1          1      0.995      0.937
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      5.79G     0.5103     0.2449     0.8495         21        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         93        300          1          1      0.995      0.937
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100       5.8G     0.5045     0.2418      0.846         36        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                    all         93        300          1          1      0.995      0.934
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      5.82G     0.5264     0.2459     0.8527         23        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                    all         93        300          1          1      0.995      0.938
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      5.84G     0.5257      0.244     0.8536         28        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s
#                    all         93        300          1          1      0.995      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      5.85G     0.5153      0.243     0.8443         16        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      5.87G     0.5255     0.2483     0.8532         13        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         93        300          1          1      0.995      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      5.89G     0.5203     0.2416     0.8492         33        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         93        300          1          1      0.995      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100       5.9G     0.5146       0.24     0.8479         28        640: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         93        300          1          1      0.995      0.946
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      5.92G     0.5246     0.2255     0.8499         14        640: 100% ━━━━━━━━━━━━ 24/24 1.8it/s 13.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                    all         93        300          1          1      0.995      0.941
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      5.94G     0.5315     0.2258      0.848         17        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      5.96G     0.5007      0.216     0.8445         17        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1s
#                    all         93        300          1          1      0.995      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      5.98G     0.4978     0.2137     0.8437         14        640: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                    all         93        300          1          1      0.995      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      5.99G      0.499     0.2132     0.8412         20        640: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.3s
#                    all         93        300          1          1      0.995      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      6.01G     0.4844     0.2095     0.8374          8        640: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s
#                    all         93        300          1          1      0.995       0.94
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      6.03G     0.4899     0.2118     0.8384         17        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         93        300          1          1      0.995      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      6.04G      0.491     0.2077     0.8376         14        640: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         93        300          1          1      0.995      0.947
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      6.06G      0.487     0.2126     0.8409          8        640: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                    all         93        300          1          1      0.995      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      6.08G     0.4924     0.2093     0.8408         20        640: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.6s
#                    all         93        300          1          1      0.995      0.946
#
# 100 epochs completed in 0.343 hours.
# Optimizer stripped from /content/runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from /content/runs/detect/train/weights/best.pt, 6.2MB
#
# Validating /content/runs/detect/train/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2s
#                    all         93        300          1          1      0.995      0.947
# Speed: 0.2ms preprocess, 2.0ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to /content/runs/detect/train

# %% [markdown]
# 5. Teste e avaliação

# %%
metrics = model.val()

print(f"Map50-95: {metrics.box.map}") # Precisão média

metrics_test = model.val(split='test')
print(f"Precisão no mundo real: {metrics_test.box.map:.4f}")

from IPython.display import Image
Image(filename=f'{model.trainer.save_dir}/val_batch0_pred.jpg')
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 643.3±339.2 MB/s, size: 19.0 KB)
# val: Scanning /content/red-2/valid/labels.cache... 93 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 93/93 190.5Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.2s
#                    all         93        300          1          1      0.995      0.948
# Speed: 4.2ms preprocess, 5.3ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to /content/runs/detect/val
# Map50-95: 0.9475122185955842
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 204.0±47.2 MB/s, size: 9.7 KB)
# val: Scanning /content/red-2/test/labels... 93 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 93/93 1.6Kit/s 0.1s
# val: New cache created: /content/red-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s
#                    all         93        333          1          1      0.995      0.945
# Speed: 5.2ms preprocess, 4.6ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to /content/runs/detect/val2
# Precisão no mundo real: 0.9447

# %% [markdown]
# 6. exportar para TFLite (Edge TPU / CPU)

# %%
print("Exportando modelo para formato TFLite...")

# Exporta com quantização INT8 (máxima velocidade no Raspberry Pi)
# O formato 'tflite' gera um arquivo best_saved_model/best_float32.tflite ou int8
success = model.export(format='tflite', int8=True)

print(f"Local da exportação: {success}")

# O YOLO geralmente salva em runs/detect/train/weights/best_saved_model/
# Vamos encontrar e baixar o arquivo .tflite
import glob
tflite_files = glob.glob("runs/detect/train*/weights/*tflite")
if tflite_files:
    latest_file = tflite_files[0] # Pega o arquivo gerado
    print(f"Baixando: {latest_file}")
    files.download(latest_file)
else:
    print("Arquivo TFLite não encontrado no caminho padrão. Verifique a pasta 'runs'.")
# Out:
# Exportando modelo para formato TFLite...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
#
# PyTorch: starting from '/content/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0,<=1.19.1', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 20 packages in 2.83s
# Prepared 11 packages in 5.28s
# Installed 11 packages in 272ms
#  + ai-edge-litert==2.0.3
#  + backports-strenum==1.3.1
#  + colorama==0.4.6
#  + coloredlogs==15.0.1
#  + humanfriendly==10.0
#  + onnx==1.19.1
#  + onnx-graphsurgeon==0.5.8
#  + onnx2tf==1.28.5
#  + onnxruntime-gpu==1.23.2
#  + onnxslim==0.1.78
#  + sng4onnx==1.0.4
#
# requirements: AutoUpdate success ✅ 9.1s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=coco8.yaml'
#
# WARNING ⚠️ Dataset 'coco8.yaml' images not found, missing path '/content/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/content/datasets/coco8.zip': 100% ━━━━━━━━━━━━ 432.8KB 21.6MB/s 0.0s
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% ━━━━━━━━━━━━ 25/25 3.2Kfiles/s 0.0s
# Dataset download success ✅ (0.3s), saved to /content/datasets
#
# Fast image access ✅ (ping: 0.0±0.0 ms, read: 1643.6±713.9 MB/s, size: 54.0 KB)
# Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 1.2Kit/s 0.0s
# New cache created: /content/datasets/coco8/labels/val.cache
# WARNING ⚠️ TensorFlow SavedModel: >300 images recommended for INT8 calibration, found 4 images.
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.78...
# ONNX: export success ✅ 1.3s, saved as '/content/runs/detect/train/weights/best.onnx' (11.8 MB)
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip': 100% ━━━━━━━━━━━━ 1.1MB 34.1MB/s 0.0s
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /content/calibration_image_sample_data_20x128x128x3_float32.npy...: 100% ━━━━━━━━━━━━ 1/1 32.2files/s 0.0s
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.5...
# Saved artifact at '/content/runs/detect/train/weights/best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 5, 8400), dtype=tf.float32, name=None)
# Captures:
#   140580190366864: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140580190367440: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   140580190367632: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140580190369168: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140580190370896: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   140580190370320: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140579914089104: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   140579914088912: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140579914090256: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914089872: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914092176: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   140579914092752: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140579914089488: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   140579914089296: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140579914090832: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914090448: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914092944: TensorSpec(shape=(1, 1, 48, 32), dtype=tf.float32, name=None)
#   140579914093520: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140579914091792: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140579914093904: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   140579914091600: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579914094096: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140579914093712: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579914095056: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914094288: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914095440: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140579914096400: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140579914092368: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140579914093136: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140579914095632: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140579914096592: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140579914093328: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140579914096976: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140579914094480: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914094864: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914097360: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   140579914096784: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579914097552: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140579914095824: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   140579914097168: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579914097936: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   140579914098128: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579914098704: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914098512: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914100624: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579914100816: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579914098320: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579914097744: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579914100048: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579914101008: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579914099664: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579914101392: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579914098896: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914099088: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914101776: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   140579914101200: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579914101968: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140579914100240: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   140579914101584: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140579914102352: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   140579914102544: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140579914103120: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914102928: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914104656: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140579914102736: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579914104080: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140579914104464: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579914103312: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914103504: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579914103888: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   140579914102160: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140579474702800: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   140579474702992: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579474703376: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   140579474703184: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140579474704144: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   140579474704336: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579474704720: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474703952: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474706064: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579474706256: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474704528: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579474703568: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474705488: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474703760: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474707024: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   140579474706832: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579474705680: TensorSpec(shape=(1, 1, 192, 64), dtype=tf.float32, name=None)
#   140579474705872: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474707600: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474707408: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474709520: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140579474709712: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140579474707216: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140579474705296: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140579474707792: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474707984: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474710096: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   140579474709904: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474710288: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140579474708944: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579474708560: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474712208: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   140579474711632: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579474713360: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474713168: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474715856: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579474716048: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474714896: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579474716432: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474713744: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474713936: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579474713552: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   140579474714512: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579474716624: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140579474712784: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140579474715472: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579474716240: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   140579474717776: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140579467051664: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579467051472: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579467051856: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140579467052816: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579467054160: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140579467054736: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140579467052048: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579467052240: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140579467053200: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   140579467054928: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140579467054544: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   140579467053968: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   140579474717008: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   140579474715664: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   140579474711056: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579474710672: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579467051280: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579467054352: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474716816: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474717392: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474709136: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474710480: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579467055504: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579467053392: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579474718160: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579474715088: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579474711824: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579474710864: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140579467055120: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579467055312: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474717200: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474717584: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474711440: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474711248: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579467056272: TensorSpec(shape=(1, 1, 64, 1), dtype=tf.float32, name=None)
#   140579467055696: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140579474718352: TensorSpec(shape=(1, 1, 64, 1), dtype=tf.float32, name=None)
#   140579474717968: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140579474712976: TensorSpec(shape=(1, 1, 64, 1), dtype=tf.float32, name=None)
#   140579474712592: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140579467056080: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579467055888: TensorSpec(shape=(1,), dtype=tf.float32, name=None)
#   140579474718544: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579467051088: TensorSpec(shape=(1,), dtype=tf.float32, name=None)
#   140579474712016: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140579474712400: TensorSpec(shape=(1,), dtype=tf.float32, name=None)
#   140579467058576: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   140579467058768: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140579467058192: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140579467053776: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140579467057040: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140579467059152: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   140579467058384: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#
#
# TensorFlow SavedModel: export success ✅ 63.8s, saved as '/content/runs/detect/train/weights/best_saved_model' (38.9 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as '/content/runs/detect/train/weights/best_saved_model/best_int8.tflite' (3.2 MB)
#
# Export complete (64.1s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=/content/runs/detect/train/weights/best_saved_model/best_int8.tflite imgsz=640 int8
# Validate:        yolo val task=detect model=/content/runs/detect/train/weights/best_saved_model/best_int8.tflite imgsz=640 data=/content/red-2/data.yaml int8
# Visualize:       https://netron.app
# Local da exportação: /content/runs/detect/train/weights/best_saved_model/best_int8.tflite
# Arquivo TFLite não encontrado no caminho padrão. Verifique a pasta 'runs'.
